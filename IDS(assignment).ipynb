# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data =  pd.read_csv("the-hello-dataset-fa22.csv")
data.head()
# Out:
#                   Name  Gender HSSC-1 HSSC-2  CGPA FavoriteColor BirthMonth  \
# 0       Muhammad Usman    Male    440    369   2.8         Black      March
# 1          Taha Ishfaq    Male    415    408  2.73           Red      March
# 2      Muhammad Hamdan    Male    388    321  2.78         Black    October
# 3  Syeda Maham Gillani  Female    412    440  3.11          Blue   February
# 4           Umar Wasim    Male    364    469  2.42         black   October
#
#   Weight
# 0     77
# 1     72
# 2     53
# 3     63
# 4     80

# %%
new_data = data[['Name']].copy()
print(new_data)
# Out:
#                     Name
# 0         Muhammad Usman
# 1            Taha Ishfaq
# 2        Muhammad Hamdan
# 3    Syeda Maham Gillani
# 4             Umar Wasim
# ..                   ...
# 129     M Abubakar Malik
# 130         Muhammad Ali
# 131         shafaqat ali
# 132          Ammar Asif
# 133      Muhammad Zubair
#
# [134 rows x 1 columns]

# %%
data[data['Name'].str.count('^[H].*')>0]
# Out:
#                     Name  Gender HSSC-1 HSSC-2  CGPA FavoriteColor  \
# 9           Hamza Naveed    Male    954    459   2.8          Blue
# 21           Habib Ullah    Male    399    434  3.35       Mustard
# 22          Hunain Javed    Male    362    413  2.94         Black
# 58  Hafiz Malahim Labib.    Male    390    430  3.24        Orange
# 60   HAMNA TARIQ SALEEMI  Female    400    418   2.8         Black
# 77                  Hina  Female    410    350   2.9          Blue
# 78      Hamza Javed Khan    Male    400    381  3.39          Blue
# 80        Husnain Ahmed     Male    335    427  2.41     Dark blue
# 93      Hamayoun Masroor    Male    900    856  3.16          Pink
# 98         Hussain afzal    Male    415    346  2.87          Blue
#
#     BirthMonth Weight
# 9          May     58
# 21       April     60
# 22  September      76
# 58         May     54
# 60     October     62
# 77      August     67
# 78    January      78
# 80   September     72
# ...

# %%
new_data = pd.read_csv("the-hello-dataset-fa22-new.csv")

# %%
name_data = new_data[['Name','Middle Name','Last Name']].copy()
print(name_data)
# Out:
#          Name Middle Name Last Name
# 0    Muhammad         NaN       NaN
# 1        Taha         NaN       NaN
# 2    Muhammad      Hamdan       NaN
# 3       Syeda       Maham   Gillani
# 4        Umar       Wasim       NaN
# ..        ...         ...       ...
# 129         M    Abubakar     Malik
# 130  Muhammad         Ali       NaN
# 131  shafaqat         ali       NaN
# 132     Ammar        Asif       NaN
# 133  Muhammad      Zubair       NaN
#
# [134 rows x 3 columns]

# %%
new_data[new_data['Last Name'].str.count('w*')>0]
# Out:
#          Name Middle Name Last Name  Gender    HSSC-2   CGPA FavoriteColor  \
# 3       Syeda       Maham   Gillani  Female       440   3.11          Blue
# 6    Shahzada     Mujahid      Raza    Male       466    3.2        Orange
# 14   Muhammad      Subhan      Khan    Male       419   3.53        Yellow
# 17     SARMAD      WAHEED     AHMED    Male       427   3.47         Green
# 20          M     Hassaan    Lateef    Male       450    2.8         Black
# 23      Ahmed       Amjad       Dar    Male       432   2.71         Black
# 26   Muhammad     Ibrahim    Khalil    Male       357   2.88         Blue
# 32   Muhammad        saim     jamil    Male       849   2.85          blue
# 33      Ahmar      Hafeez      Khan    Male       397   2.81        Yellow
# 39   Muhammad        Umar    Asghar    Male       333   2.23         Black
# 42   MUHAMMAD      HAIDER      AWAN    Male       425   2.56          Blue
# ...

# %%
new_data['CGPA'] = new_data.CGPA

# %%
gender=new_data["Gender"]
name=new_data["Name"]

# %%
plt.pie(gender, labels=name, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 plt.pie(gender, labels=name, explode=explode, colors=colors,
#       2 autopct='%1.1f%%', shadow=True, startangle=140)
#
# NameError: name 'explode' is not defined
